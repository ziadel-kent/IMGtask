# %% [markdown]
# <a href="https://colab.research.google.com/github/ziadel-kent/IMGtask/blob/main/ImageProcessor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from IPython.display import display
from PIL import Image
import io


class ImageProcessor:
    def adjust_brightness_contrast(self, image, alpha=1.2, beta=10):
        return cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

    def apply_gaussian_blur(self, image, kernel=(7, 7)):
        return cv2.GaussianBlur(image, kernel, 0)

    def apply_denoising(self, image):
        return cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)

    def apply_canny_edge(self, image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        return cv2.Canny(gray, 100, 200)

    def extract_features(self, image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        sift = cv2.SIFT_create()
        keypoints, descriptors = sift.detectAndCompute(gray, None)
        return keypoints, descriptors


def upload_image():
    uploaded = files.upload()
    for filename in uploaded.keys():
        image = cv2.imdecode(np.frombuffer(uploaded[filename], np.uint8), cv2.IMREAD_COLOR)
        return image


def show_image(img, title="الصورة"):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8,6))
    plt.imshow(img_rgb)
    plt.title(title)
    plt.axis("off")
    plt.show()


def save_image(img, filename='processed.jpg'):
    cv2.imwrite(filename, img)
    files.download(filename)


processor = ImageProcessor()

print("📂 حمّل صورة لاستخدامها")
image = upload_image()

if image is not None:
    show_image(image, " Original")

    adjusted = processor.adjust_brightness_contrast(image)
    blurred = processor.apply_gaussian_blur(adjusted)
    denoised = processor.apply_denoising(blurred)
    edges = processor.apply_canny_edge(denoised)
    keypoints, descriptors = processor.extract_features(denoised)

    print(f"🔍 Number of features extracted: {len(descriptors) if descriptors is not None else 0}")


    show_image(adjusted, "✨Brightness/Contrast")
    show_image(blurred, "🌫️  Gaussian Blur")
    show_image(denoised, "🔇Denoised")
    show_image(cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR), "🪒 Canny Edges")


    save_image(denoised, "final_result.jpg")
# Out:
# 📂 حمّل صورة لاستخدامها
#      <input type="file" id="files-8e1c26bf-87ab-4de0-928c-ef82667b6eab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e1c26bf-87ab-4de0-928c-ef82667b6eab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from IPython.display import display
from PIL import Image
import io


class ImageProcessor:
    def adjust_brightness_contrast(self, image, alpha=1.2, beta=10):
        return cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

    def apply_gaussian_blur(self, image, kernel=(7, 7)):
        return cv2.GaussianBlur(image, kernel, 0)

    def apply_denoising(self, image):
        return cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)

    def apply_canny_edge(self, image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        return cv2.Canny(gray, 100, 200)

    def extract_features(self, image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        sift = cv2.SIFT_create()
        keypoints, descriptors = sift.detectAndCompute(gray, None)
        return keypoints, descriptors


def upload_image():
    uploaded = files.upload()
    for filename in uploaded.keys():
        image = cv2.imdecode(np.frombuffer(uploaded[filename], np.uint8), cv2.IMREAD_COLOR)
        return image


def show_image(img, title="الصورة"):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8,6))
    plt.imshow(img_rgb)
    plt.title(title)
    plt.axis("off")
    plt.show()


def save_image(img, filename='processed.jpg'):
    cv2.imwrite(filename, img)
    files.download(filename)


processor = ImageProcessor()

print("📂 حمّل صورة لاستخدامها")
image = upload_image()

if image is not None:
    show_image(image, " Original")

    adjusted = processor.adjust_brightness_contrast(image)
    blurred = processor.apply_gaussian_blur(adjusted)
    denoised = processor.apply_denoising(blurred)
    edges = processor.apply_canny_edge(denoised)
    keypoints, descriptors = processor.extract_features(denoised)

    print(f"🔍 Number of features extracted: {len(descriptors) if descriptors is not None else 0}")


    show_image(adjusted, "✨Brightness/Contrast")
    show_image(blurred, "🌫️  Gaussian Blur")
    show_image(denoised, "🔇Denoised")
    show_image(cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR), "🪒 Canny Edges")


    save_image(denoised, "final_result.jpg")
# Out:
# 📂 حمّل صورة لاستخدامها
#      <input type="file" id="files-c009f311-a4a5-4849-9ff8-bbf13bd50a30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c009f311-a4a5-4849-9ff8-bbf13bd50a30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
